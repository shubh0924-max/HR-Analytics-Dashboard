# %%
avg_income = df.groupby("Department")["Monthly_Income"].mean()

plt.figure(figsize=(8,4))

plt.plot(
    avg_income.index,
    avg_income.values,
    marker="o",
    linewidth=2
)

plt.title("Average Monthly Income by Department")
plt.xlabel("Department")
plt.ylabel("Average Monthly Income")

plt.grid(True)

plt.show()

# %%
avg_income = df.groupby("Department")["Monthly_Income"].mean()

plt.figure(figsize=(8,4))

plt.plot(
    avg_income.index,
    avg_income.values,
    marker="o",
    linewidth=2
)

plt.title("Average Monthly Income by Department")
plt.xlabel("Department")
plt.ylabel("Average Monthly Income")

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(7,4))

plt.hist(
    df["Work_Life_Balance"],
    bins=5
)

plt.title("Work-Life Balance Distribution")
plt.xlabel("Work-Life Balance Rating")
plt.ylabel("Number of Employees")

plt.show()

# %%
avg_income = df.groupby("Years_at_Company")["Monthly_Income"].mean()

plt.figure(figsize=(8,5))

plt.plot(
    avg_income.index,
    avg_income.values,
    marker="o",
    linewidth=2
)

plt.title("Average Monthly Income by Years at Company")
plt.xlabel("Years at Company")
plt.ylabel("Average Monthly Income")

plt.grid(True)

plt.show()

# %%
attrition_age = pd.crosstab(df["Age_Group"], df["Attrition"])

attrition_age.plot(
    kind="barh",
    stacked=True,
    figsize=(8,5)
)

plt.title("Attrition by Age Group")
plt.xlabel("Employee Count")
plt.ylabel("Age Group")

plt.show()

# %%
experience = df["Experience_Level"].value_counts().sort_index()

plt.figure(figsize=(8,4))

plt.barh(experience.index.astype(str), experience.values)

plt.title("Employee Distribution by Experience Level")
plt.xlabel("Number of Employees")
plt.ylabel("Experience Level")

plt.show()

# %%
income = df["Income_Band"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    income.values,
    labels=income.index,
    autopct="%1.1f%%",
    startangle=90,
    wedgeprops={"width":0.4}
)

plt.title("Income Band Distribution")

plt.show()

# %%
age = df["Age_Group"].value_counts().sort_index()

plt.figure(figsize=(8,4))

plt.plot(
    age.index.astype(str),
    age.values,
    marker="o",
    linewidth=2
)

plt.title("Employees by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Employee Count")

plt.grid(True)

plt.show()

# %%
gender = df["Gender"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    gender.values,
    labels=gender.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Gender Distribution")

plt.show()

# %%
department = df["Department"].value_counts()

plt.figure(figsize=(8,5))

plt.barh(department.index, department.values)

plt.title("Employees by Department")
plt.xlabel("Employee Count")
plt.ylabel("Department")

plt.show()

# %%
attrition = df["Attrition"].value_counts()

plt.figure(figsize=(6,4))

plt.bar(attrition.index, attrition.values)

plt.title("Employee Attrition Distribution")
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")

plt.show()

# %%
df = pd.read_csv("HR_Analytics_Cleaned.csv")

# %% [markdown]
# # DATA VISUALIZATION

# %%
df = pd.read_csv("HR_Analytics_Cleaned.csv")

# %%
df.columns.tolist()
# Out:
# ['Employee_ID',
#  'Age',
#  'Gender',
#  'Marital_Status',
#  'Department',
#  'Job_Role',
#  'Job_Level',
#  'Monthly_Income',
#  'Hourly_Rate',
#  'Years_at_Company',
#  'Years_in_Current_Role',
#  'Years_Since_Last_Promotion',
#  'Work_Life_Balance',
#  'Job_Satisfaction',
#  'Performance_Rating',
#  'Training_Hours_Last_Year',
#  'Overtime',
#  'Project_Count',
#  'Average_Hours_Worked_Per_Week',
#  'Absenteeism',
#  'Work_Environment_Satisfaction',
#  'Relationship_with_Manager',
#  'Job_Involvement',
#  'Distance_From_Home',
#  'Number_of_Companies_Worked',
#  'Attrition',
#  'Age_Group',
#  'Income_Band',
#  'Experience_Level',
#  'Distance_Category',
#  'Working_Hours_Category']

# %%
df.to_csv("HR_Analytics_Cleaned.csv", index=False)

# %%
df.shape
# Out:
# (10000, 31)

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Marital_Status', 'Department',
#        'Job_Role', 'Job_Level', 'Monthly_Income', 'Hourly_Rate',
#        'Years_at_Company', 'Years_in_Current_Role',
#        'Years_Since_Last_Promotion', 'Work_Life_Balance', 'Job_Satisfaction',
#        'Performance_Rating', 'Training_Hours_Last_Year', 'Overtime',
#        'Project_Count', 'Average_Hours_Worked_Per_Week', 'Absenteeism',
#        'Work_Environment_Satisfaction', 'Relationship_with_Manager',
#        'Job_Involvement', 'Distance_From_Home', 'Number_of_Companies_Worked',
#        'Attrition', 'Age_Group', 'Income_Band', 'Experience_Level',
#        'Distance_Category', 'Working_Hours_Category'],
#       dtype='str')

# %%
df["Working_Hours_Category"] = pd.cut(
    df["Average_Hours_Worked_Per_Week"],
    bins=[0, 35, 40, 45, 60],
    labels=["Part Time", "Normal", "Extended", "Heavy"]
)

# %%
df["Distance_Category"] = pd.cut(
    df["Distance_From_Home"],
    bins=[0, 5, 10, 20, 50],
    labels=["Very Near", "Near", "Moderate", "Far"]
)

# %%
df["Experience_Level"] = pd.cut(
    df["Years_at_Company"],
    bins=[0, 2, 5, 10, 20, 40],
    labels=["New", "Junior", "Mid-Level", "Senior", "Veteran"]
)

# %%
df["Income_Band"] = pd.cut(
    df["Monthly_Income"],
    bins=[0, 5000, 10000, 15000, 20000],
    labels=["Low", "Medium", "High", "Very High"]
)

# %%
df[["Age", "Age_Group"]].head(10)
# Out:
#    Age Age_Group
# 0   58     56-65
# 1   48     46-55
# 2   34     26-35
# 3   27     26-35
# 4   40     36-45
# 5   58     56-65
# 6   38     36-45
# 7   42     36-45
# 8   30     26-35
# 9   30     26-35

# %%
df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[18, 25, 35, 45, 55, 65],
    labels=["18-25", "26-35", "36-45", "46-55", "56-65"]
)

# %%
df.groupby("Attrition")["Monthly_Income"].mean().round(2)
# Out:
# Attrition
# No     11436.39
# Yes    11438.04
# Name: Monthly_Income, dtype: float64

# %%
df.groupby("Department")["Monthly_Income"].mean().round(2)
# Out:
# Department
# Finance      11563.93
# HR           11574.49
# IT           11407.76
# Marketing    11295.09
# Sales        11354.72
# Name: Monthly_Income, dtype: float64

# %%
pd.crosstab(
    df["Overtime"],
    df["Attrition"],
    normalize="index"
).round(2) * 100
# Out:
# Attrition    No   Yes
# Overtime
# No         80.0  20.0
# Yes        80.0  20.0

# %%
jobrole_attrition = pd.crosstab(
    df["Job_Role"],
    df["Attrition"],
    normalize="index"
) * 100

jobrole_attrition.round(2)
# Out:
# Attrition     No    Yes
# Job_Role
# Analyst    79.78  20.22
# Assistant  78.57  21.43
# Executive  79.93  20.07
# Manager    81.94  18.06

# %%
department_attrition = pd.crosstab(
    df["Department"],
    df["Attrition"],
    normalize="index"
) * 100

department_attrition.round(2)
# Out:
# Attrition      No    Yes
# Department
# Finance     79.15  20.85
# HR          80.49  19.51
# IT          79.65  20.35
# Marketing   80.64  19.36
# Sales       80.18  19.82

# %%
pd.crosstab(df["Department"], df["Attrition"])
# Out:
# Attrition     No  Yes
# Department
# Finance     1575  415
# HR          1572  381
# IT          1526  390
# Marketing   1720  413
# Sales       1610  398

# %%
df["Department"].value_counts()
# Out:
# Department
# Marketing    2133
# Sales        2008
# Finance      1990
# HR           1953
# IT           1916
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    5042
# Male      4958
# Name: count, dtype: int64

# %%
round(df["Attrition"].value_counts(normalize=True) * 100, 2)
# Out:
# Attrition
# No     80.03
# Yes    19.97
# Name: proportion, dtype: float64

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     8003
# Yes    1997
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Employee_ID                      0
# Age                              0
# Gender                           0
# Marital_Status                   0
# Department                       0
# Job_Role                         0
# Job_Level                        0
# Monthly_Income                   0
# Hourly_Rate                      0
# Years_at_Company                 0
# Years_in_Current_Role            0
# Years_Since_Last_Promotion       0
# Work_Life_Balance                0
# Job_Satisfaction                 0
# Performance_Rating               0
# Training_Hours_Last_Year         0
# Overtime                         0
# Project_Count                    0
# Average_Hours_Worked_Per_Week    0
# Absenteeism                      0
# Work_Environment_Satisfaction    0
# Relationship_with_Manager        0
# Job_Involvement                  0
# Distance_From_Home               0
# Number_of_Companies_Worked       0
# Attrition                        0
# Age_Group                        0
# ...

# %%
df.describe()
# Out:
#        Employee_ID           Age     Job_Level  Monthly_Income   Hourly_Rate  \
# count  10000.00000  10000.000000  10000.000000    10000.000000  10000.000000
# mean    5000.50000     39.561800      2.990800    11436.716700     57.032300
# std     2886.89568     11.454986      1.410643     4926.528302     24.703261
# min        1.00000     20.000000      1.000000     3000.000000     15.000000
# 25%     2500.75000     30.000000      2.000000     7182.500000     36.000000
# 50%     5000.50000     40.000000      3.000000    11401.500000     57.000000
# 75%     7500.25000     49.000000      4.000000    15679.500000     78.000000
# max    10000.00000     59.000000      5.000000    19999.000000     99.000000
#
#        Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# count      10000.000000           10000.000000                10000.000000
# mean          14.936200               7.451300                    4.471900
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  str
#  3   Marital_Status                 10000 non-null  str
#  4   Department                     10000 non-null  str
#  5   Job_Role                       10000 non-null  str
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
#  12  Work_Life_Balance              10000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Marital_Status', 'Department',
#        'Job_Role', 'Job_Level', 'Monthly_Income', 'Hourly_Rate',
#        'Years_at_Company', 'Years_in_Current_Role',
#        'Years_Since_Last_Promotion', 'Work_Life_Balance', 'Job_Satisfaction',
#        'Performance_Rating', 'Training_Hours_Last_Year', 'Overtime',
#        'Project_Count', 'Average_Hours_Worked_Per_Week', 'Absenteeism',
#        'Work_Environment_Satisfaction', 'Relationship_with_Manager',
#        'Job_Involvement', 'Distance_From_Home', 'Number_of_Companies_Worked',
#        'Attrition', 'Age_Group', 'Income_Band', 'Experience_Level',
#        'Distance_Category', 'Working_Hours_Category'],
#       dtype='str')

# %%
df.shape
# Out:
# (10000, 26)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Shubham\Downloads\project\HR dataset.csv")

df.head()
# Out:
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58    Male         Single    Finance    Manager          5
# 1            2   48  Female       Divorced         HR  Assistant          4
# 2            3   34  Female        Married  Marketing    Manager          4
# 3            4   27  Female       Divorced         HR    Manager          4
# 4            5   40    Male        Married         HR    Analyst          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 0            7332           81                24  ...        No
# 1            6069           55                18  ...       Yes
# 2           11485           65                 6  ...       Yes
# 3           18707           28                12  ...        No
# 4           16398           92                 3  ...        No
#
#    Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# ...

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5
